# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
import os
if not os.path.isdir("Deep_Learning"):
    os.makedirs("Deep_Learning")

# %%
# %cd Deep_Learning
# Out:
# /content/gdrive/MyDrive/Deep_Learning

# %%
# %cd yolov8
# Out:
# /content/gdrive/MyDrive/Deep_Learning/yolov8

# %%
# %cd ultralytics
# Out:
# /content/gdrive/MyDrive/Deep_Learning/yolov8/ultralytics

# %%
# %pwd
# Out:
# '/content/gdrive/MyDrive/Deep_Learning/yolov8/ultralytics'

# %%
# !pip install IPython

# %%
# !pip install ultralytics

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.61 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/112.6 GB disk)

# %%
# %cd /content/gdrive/MyDrive/Deep_Learning/yolov8
# Out:
# /content/gdrive/MyDrive/Deep_Learning/yolov8

# %%
# !pip install -r requirements.txt

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/gdrive/MyDrive/Deep_Learning/yolov8/data1/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.61 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/gdrive/MyDrive/deep_learning2/yoloV8/runs/detect/train4/weights/best.pt source="/content/gdrive/MyDrive/Deep_Learning/yolov8/data1/test/images" save=True
# Out:
# /bin/bash: line 1: yolo: command not found
